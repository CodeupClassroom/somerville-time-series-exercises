# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from math import sqrt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.api import Holt, ExponentialSmoothing
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# Reading in our store data.

# %%
df = pd.read_csv('stores.csv', index_col=0)
df.head()
# Out:
#             sale_amount  item_brand  \
# sale_date
# 2013-01-01           13    Riceland
# 2013-01-01           26     Mueller
# 2013-01-01           27  Mama Marys
# 2013-01-01           54     Mueller
# 2013-01-01           35     Mueller
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01                                        Pizza Sauce        4.65
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
# 2013-01-01  Mueller Sport Care Basic Support Level Medium ...        8.40
#
#                      store_address  store_zipcode   store_city store_state  \
# sale_date
# 2013-01-01  12125 Alamo Ranch Pkwy          78253  San Antonio          TX
# 2013-01-01  12018 Perrin Beitel Rd          78217  San Antonio          TX
# 2013-01-01  12018 Perrin Beitel Rd          78217  San Antonio          TX
# 2013-01-01     15000 San Pedro Ave          78232  San Antonio          TX
# 2013-01-01      735 SW Military Dr          78221  San Antonio          TX
#
#               month day_of_week  sales_total
# sale_date
# 2013-01-01  January     Tuesday        10.92
# 2013-01-01  January     Tuesday       218.40
# 2013-01-01  January     Tuesday       125.55
# 2013-01-01  January     Tuesday       453.60
# 2013-01-01  January     Tuesday       294.00

# %% [markdown]
# It gets read in as a string. I have to make sure to recast it as a datetime object.

# %%
df.index = pd.to_datetime(df.index)

# %% [markdown]
# We have to split our data before we can model. I'm going to do a human-based split.

# %%
train = df.loc[:'2015']
validate = df.loc['2016']
test = df.loc['2017']

train.shape, validate.shape, test.shape
# Out:
# ((547500, 11), (183000, 11), (182500, 11))

# %% [markdown]
# We need to perform an aggregation to have one point of data per day. We can resample by the day and take the sum of the sales_total column.

# %%
day_train = train.resample('d').sales_total.sum()
day_val = validate.resample('d').sales_total.sum()
day_test = test.resample('d').sales_total.sum()

day_train.head()
# Out:
# sale_date
# 2013-01-01    73844.01
# 2013-01-02    73570.58
# 2013-01-03    78169.48
# 2013-01-04    84467.73
# 2013-01-05    87621.85
# Freq: D, Name: sales_total, dtype: float64

# %% [markdown]
# We can visualize our train/test split.

# %%
plt.plot(day_train)
plt.plot(day_val)
plt.plot(day_test)
plt.show()

# %% [markdown]
# Now that our data is properly split, let's try two different modeling approaches:
# - One baseline model (rolling average)
# - One non-baseline model (Holt's seasonal trend)

# %%
rolling = round(day_train.rolling(30).mean()[-1], 2)
rolling
# Out:
# 105739.12

# %%
preds = pd.DataFrame({'actual': day_val,
                      'month_rolling': rolling})

preds.head()
# Out:
#                actual  month_rolling
# sale_date
# 2016-01-01  107875.26      105739.12
# 2016-01-02  114330.43      105739.12
# 2016-01-03  123144.91      105739.12
# 2016-01-04   80873.97      105739.12
# 2016-01-05   95429.90      105739.12

# %% [markdown]
# We can also create a rolling average of the last 180 days in our dataset. This may perform better (or worse) than our monthly rolling average baseline.

# %%
hy_rolling = round(day_train.rolling(180).mean()[-1], 2)

# %%
preds['hy_rolling'] = hy_rolling
preds.head()
# Out:
#                actual  month_rolling  hy_rolling
# sale_date
# 2016-01-01  107875.26      105739.12   145666.45
# 2016-01-02  114330.43      105739.12   145666.45
# 2016-01-03  123144.91      105739.12   145666.45
# 2016-01-04   80873.97      105739.12   145666.45
# 2016-01-05   95429.90      105739.12   145666.45

# %% [markdown]
# Defining a simple function to evaluate our models using RMSE.

# %%
def eval_preds(df, predictions, actual='actual'):
    
    return round(sqrt(mean_squared_error(df[actual], df[predictions])), 2)

# %%
eval_preds(preds, 'month_rolling')
# Out:
# 57384.82

# %%
eval_preds(preds, 'hy_rolling')
# Out:
# 34405.71

# %% [markdown]
# Let's visualize our baselines!

# %%
plt.plot(preds['actual'])
plt.plot(preds['month_rolling'])
plt.plot(preds['hy_rolling'])
plt.show()

# %% [markdown]
# Things I passed into my model:
# - My train dataset
# - The number of observations before the seasonality repeats (365)
# - The type of trend in my dataset (it's additive)
# - Seasonality is also set to additive
#
# Finally, hiding at the end, I am calling the .fit() method on my model.

# %%
hst_model = ExponentialSmoothing(day_train, seasonal_periods=365, trend='add', seasonal='add').fit()
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %% [markdown]
# When I am calling the .forecast() method on my model object, I specify how many observations to produce. In this case, I am asking for a number of observations equal to the days in the validate dataset.

# %%
hst_model.forecast(day_val.shape[0])
# Out:
# 2016-01-01    100114.134028
# 2016-01-02    108505.451715
# 2016-01-03    112492.190484
# 2016-01-04    120205.367567
# 2016-01-05    104386.511068
#                   ...
# 2016-12-27    133416.358399
# 2016-12-28    115047.490633
# 2016-12-29    105504.232098
# 2016-12-30    110782.483640
# 2016-12-31    111645.544104
# Freq: D, Length: 366, dtype: float64

# %% [markdown]
# I will add this predictions to my predictions dataframe so I can evaluate them!

# %%
preds['hst'] = hst_model.forecast(day_val.shape[0])

# %% [markdown]
# After evaluating my predictions, I see that my model outperforms both baselines.

# %%
eval_preds(preds, 'hst')
# Out:
# 25942.97

# %% [markdown]
# Let's take a peek at the model's performance against my actual dataset.

# %%
plt.plot(preds['actual'], alpha=0.5)
plt.plot(preds['hy_rolling'])
plt.plot(preds['hst'])
plt.show()
