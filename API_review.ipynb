# %% [markdown]
# API exercises:

# %% [markdown]
# Goals with this exercise set:
#  - Acquire all people
#  - Acquire all starships
#  - Acquire all planets
# Get the Weather data at 'https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv'

# %%
import pandas as pd
import requests

# %%
# lets grab stuff the same way we did initally:

# %%
# steps that we know that we need to do:
# get the first page of content
# get the url endpoint for the next page of content
# get a dataframe, get our next location

# %%
home_url = 'https://swapi.dev/api'

# %%
# initial request:
# put the contents of the home page in home_page
home_page = requests.get(home_url).json()

# %%
# first endpoint for payload number one:
home_page['people']
# Out:
# 'https://swapi.dev/api/people/'

# %%
# plug that endpoint into a new requests
payload = requests.get(home_page['people'])

# %%
payload.json().keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
# things that I want from this first payload:
# results -> the stuff that im going to turn into a dataframe
# next -> my next payload endpoint that I need for another page

# %%
# lets make a function to automate this for all three datasets:

# %%
def get_content(topic_page)->pd.DataFrame:
    '''
    get_content is meant to interact with the star wars api
    at swapi.dev.
    
    under the presumption of the structure of any of the pages
    following the topics under the home page of swapi.dev,
    get_content will traverse the pages of content
    associated with that topic,
    grab all rows of content,
    concatenate those rows of content into a single dataframe
    and return out the complete data set as a complete pandas 
    dataframe
    '''
    # step one:
    # the arg in this is going to be the endpoint of the topic
    # payload will be from the json() version of the response
    print('getting page number 1')
    payload = requests.get(topic_page).json()
    # payload is a dictionary, get the values associated with
    # the next endpoint:
    next_page = payload['next']
    # content is going to be a list of dictionaries
    content = payload['results']
    df = pd.DataFrame(content)
    # under the condition that we still have a next page:
    while next_page is not None:
        # get the next page of content
        payload = requests.get(next_page).json()
        # grab the next endpoint
        print(f'getting page number {next_page[-1]}')
        next_page = payload['next']
        # get the content
        content = payload['results']
        # reassign the dataframe with the new content added
        df = pd.concat(
            [
            df, pd.DataFrame(content)
            ], ignore_index=True)
    return df

# %%
# topic page example:
home_page['people']
# Out:
# 'https://swapi.dev/api/people/'

# %%
import time

# %%
t0 = time.time()
people = get_content(home_page['people'])
tx = time.time()
print(f'Data obtained! We aquired the data in {round(((tx - t0) / 60),2)} minutes')
# Out:
# getting page number 1
# getting page number 2
# getting page number 3
# getting page number 4
# getting page number 5
# getting page number 6
# getting page number 7
# getting page number 8
# getting page number 9
# Data obtained! We aquired the data in 0.53 minutes

# %%
t0 = time.time()
starships = get_content(home_page['starships'])
tx = time.time()
print(f'Data obtained! We aquired the data in {round(((tx - t0) / 60),2)} minutes')
# Out:
# getting page number 1
# getting page number 2
# getting page number 3
# getting page number 4
# Data obtained! We aquired the data in 0.16 minutes

# %%
t0 = time.time()
planets = get_content(home_page['planets'])
tx = time.time()
print(f'Data obtained! We aquired the data in {round(((tx - t0) / 60),2)} minutes')
# Out:
# getting page number 1
# getting page number 2
# getting page number 3
# getting page number 4
# getting page number 5
# getting page number 6
# Data obtained! We aquired the data in 0.22 minutes

# %%
# lets get these dataframes associated with eachother

# %%
# how do people link to starships?
# people drive starships I think

# %%
starships.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    36 non-null     object
#  1   model                   36 non-null     object
#  2   manufacturer            36 non-null     object
#  3   cost_in_credits         36 non-null     object
#  4   length                  36 non-null     object
#  5   max_atmosphering_speed  36 non-null     object
#  6   crew                    36 non-null     object
#  7   passengers              36 non-null     object
#  8   cargo_capacity          36 non-null     object
#  9   consumables             36 non-null     object
#  10  hyperdrive_rating       36 non-null     object
#  11  MGLT                    36 non-null     object
#  12  starship_class          36 non-null     object
#  13  pilots                  36 non-null     object
#  14  films                   36 non-null     object
#  15  created                 36 non-null     object
#  16  edited                  36 non-null     object
#  17  url                     36 non-null     object
# dtypes: object(18)
# memory usage: 5.2+ KB

# %%
# lets look at pilots in starships as a link:
starships.pilots
# Out:
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4     [https://swapi.dev/api/people/13/, https://swa...
# 5                                                    []
# 6     [https://swapi.dev/api/people/1/, https://swap...
# 7                     [https://swapi.dev/api/people/4/]
# 8                                                    []
# 9                                                    []
# 10                   [https://swapi.dev/api/people/22/]
# 11    [https://swapi.dev/api/people/1/, https://swap...
# 12                                                   []
# 13                                                   []
# 14                   [https://swapi.dev/api/people/29/]
# 15                                                   []
# 16                                                   []
# 17                                                   []
# 18    [https://swapi.dev/api/people/11/, https://swa...
# 19                   [https://swapi.dev/api/people/39/]
# 20                   [https://swapi.dev/api/people/44/]
# 21                                                   []
# 22                                                   []
# 23    [https://swapi.dev/api/people/10/, https://swa...
# 24                   [https://swapi.dev/api/people/35/]
# 25                                                   []
# 26                                                   []
# 27    [https://swapi.dev/api/people/10/, https://swa...
# 28                                                   []
# 29                                                   []
# 30    [https://swapi.dev/api/people/10/, https://swa...
# 31    [https://swapi.dev/api/people/10/, https://swa...
# 32                                                   []
# 33                                                   []
# 34    [https://swapi.dev/api/people/10/, https://swa...
# 35                                                   []
# Name: pilots, dtype: object

# %%
# enter pd.DataFrame.explode:
# if we explode out pilots,
# the elements in those lists of those rows
# will expand out into single entries amongst
# multiple rows of a dataframe
# these exploded values link up to the people urls.
starships.explode('pilots').head()
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# 2            Sienar Fleet Systems, Cyngus Spaceworks          240000      38
# 3  Imperial Department of Military Research, Sien...   1000000000000  120000
# 4                  Corellian Engineering Corporation          100000   34.37
#
#   max_atmosphering_speed     crew passengers cargo_capacity consumables  \
# 0                    950   30-165        600        3000000      1 year
# 1                    975   47,060        n/a       36000000     2 years
# 2                   1000        5         75         180000     1 month
# 3                    n/a  342,953    843,342  1000000000000     3 years
# 4                   1050        4          6         100000    2 months
#
#   hyperdrive_rating MGLT                   starship_class  \
# 0               2.0   60                         corvette
# 1               2.0   60                   Star Destroyer
# 2               1.0   70                    landing craft
# 3               4.0   10  Deep Space Mobile Battlestation
# 4               0.5   75                  Light freighter
#
#                              pilots  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4  https://swapi.dev/api/people/13/
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2                   [https://swapi.dev/api/films/1/]
# 3                   [https://swapi.dev/api/films/1/]
# 4  [https://swapi.dev/api/films/1/, https://swapi...
#
#                        created                       edited  \
# 0  2014-12-10T14:20:33.369000Z  2014-12-20T21:23:49.867000Z
# 1  2014-12-10T15:08:19.848000Z  2014-12-20T21:23:49.870000Z
# 2  2014-12-10T15:48:00.586000Z  2014-12-20T21:23:49.873000Z
# 3  2014-12-10T16:36:50.509000Z  2014-12-20T21:26:24.783000Z
# 4  2014-12-10T16:59:45.094000Z  2014-12-20T21:23:49.880000Z
#
#                                    url
# 0   https://swapi.dev/api/starships/2/
# 1   https://swapi.dev/api/starships/3/
# 2   https://swapi.dev/api/starships/5/
# 3   https://swapi.dev/api/starships/9/
# 4  https://swapi.dev/api/starships/10/

# %%
# left key: people.url

# %%
people_and_ships = pd.merge(
left=people,
right=starships.explode('pilots'),
left_on= 'url',
right_on= 'pilots',
how='left',
suffixes=['_people', '_starships']
)

# %%
people_and_ships.shape
# Out:
# (93, 34)

# %%
people_and_ships.head()
# Out:
#       name_people height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 1  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 2           C-3PO    167   75        n/a         gold    yellow     112BBY
# 3           R2-D2     96   32        n/a  white, blue       red      33BBY
# 4     Darth Vader    202  136       none        white    yellow    41.9BBY
#
#   gender                         homeworld  \
# 0   male  https://swapi.dev/api/planets/1/
# 1   male  https://swapi.dev/api/planets/1/
# 2    n/a  https://swapi.dev/api/planets/1/
# 3    n/a  https://swapi.dev/api/planets/8/
# 4   male  https://swapi.dev/api/planets/1/
#
#                                         films_people  ... cargo_capacity  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...  ...            110
# 1  [https://swapi.dev/api/films/1/, https://swapi...  ...          80000
# 2  [https://swapi.dev/api/films/1/, https://swapi...  ...            NaN
# 3  [https://swapi.dev/api/films/1/, https://swapi...  ...            NaN
# 4  [https://swapi.dev/api/films/1/, https://swapi...  ...            150
#
#   consumables hyperdrive_rating MGLT              starship_class  \
# 0      1 week               1.0  100                 Starfighter
# 1    2 months               1.0   50  Armed government transport
# 2         NaN               NaN  NaN                         NaN
# 3         NaN               NaN  NaN                         NaN
# 4      5 days               1.0  105                 Starfighter
#
#                             pilots  \
# 0  https://swapi.dev/api/people/1/
# 1  https://swapi.dev/api/people/1/
# 2                              NaN
# 3                              NaN
# 4  https://swapi.dev/api/people/4/
#
#                                      films_starships  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/2/, https://swapi...
# 2                                                NaN
# 3                                                NaN
# 4                   [https://swapi.dev/api/films/1/]
#
#              created_starships             edited_starships  \
# 0  2014-12-12T11:19:05.340000Z  2014-12-20T21:23:49.886000Z
# 1  2014-12-15T13:04:47.235000Z  2014-12-20T21:23:49.900000Z
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4  2014-12-12T11:21:32.991000Z  2014-12-20T21:23:49.889000Z
#
#                          url_starships
# 0  https://swapi.dev/api/starships/12/
# 1  https://swapi.dev/api/starships/22/
# 2                                  NaN
# 3                                  NaN
# 4  https://swapi.dev/api/starships/13/
#
# [5 rows x 34 columns]

# %%
people.homeworld
# Out:
# 0      https://swapi.dev/api/planets/1/
# 1      https://swapi.dev/api/planets/1/
# 2      https://swapi.dev/api/planets/8/
# 3      https://swapi.dev/api/planets/1/
# 4      https://swapi.dev/api/planets/2/
#                     ...
# 77    https://swapi.dev/api/planets/59/
# 78    https://swapi.dev/api/planets/14/
# 79     https://swapi.dev/api/planets/2/
# 80    https://swapi.dev/api/planets/60/
# 81    https://swapi.dev/api/planets/12/
# Name: homeworld, Length: 82, dtype: object

# %%
# key pairing:
# people.homeworld,
# planets.url
everything = pd.merge(
left=people_and_ships,
right=planets,
how='left',
left_on='homeworld',
right_on='url')

# %%
everything.head()
# Out:
#       name_people height mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 1  Luke Skywalker    172   77      blond         fair      blue      19BBY
# 2           C-3PO    167   75        n/a         gold    yellow     112BBY
# 3           R2-D2     96   32        n/a  white, blue       red      33BBY
# 4     Darth Vader    202  136       none        white    yellow    41.9BBY
#
#   gender                         homeworld  \
# 0   male  https://swapi.dev/api/planets/1/
# 1   male  https://swapi.dev/api/planets/1/
# 2    n/a  https://swapi.dev/api/planets/1/
# 3    n/a  https://swapi.dev/api/planets/8/
# 4   male  https://swapi.dev/api/planets/1/
#
#                                         films_people  ...    climate  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...  ...       arid
# 1  [https://swapi.dev/api/films/1/, https://swapi...  ...       arid
# 2  [https://swapi.dev/api/films/1/, https://swapi...  ...       arid
# 3  [https://swapi.dev/api/films/1/, https://swapi...  ...  temperate
# 4  [https://swapi.dev/api/films/1/, https://swapi...  ...       arid
#
#       gravity                                   terrain surface_water  \
# 0  1 standard                                    desert             1
# 1  1 standard                                    desert             1
# 2  1 standard                                    desert             1
# 3  1 standard  grassy hills, swamps, forests, mountains            12
# 4  1 standard                                    desert             1
#
#    population                                          residents  \
# 0      200000  [https://swapi.dev/api/people/1/, https://swap...
# 1      200000  [https://swapi.dev/api/people/1/, https://swap...
# 2      200000  [https://swapi.dev/api/people/1/, https://swap...
# 3  4500000000  [https://swapi.dev/api/people/3/, https://swap...
# 4      200000  [https://swapi.dev/api/people/1/, https://swap...
#
#                                                films  \
# 0  [https://swapi.dev/api/films/1/, https://swapi...
# 1  [https://swapi.dev/api/films/1/, https://swapi...
# 2  [https://swapi.dev/api/films/1/, https://swapi...
# 3  [https://swapi.dev/api/films/3/, https://swapi...
# 4  [https://swapi.dev/api/films/1/, https://swapi...
#
#                        created                       edited  \
# 0  2014-12-09T13:50:49.641000Z  2014-12-20T20:58:18.411000Z
# 1  2014-12-09T13:50:49.641000Z  2014-12-20T20:58:18.411000Z
# 2  2014-12-09T13:50:49.641000Z  2014-12-20T20:58:18.411000Z
# 3  2014-12-10T11:52:31.066000Z  2014-12-20T20:58:18.430000Z
# 4  2014-12-09T13:50:49.641000Z  2014-12-20T20:58:18.411000Z
#
#                                 url
# 0  https://swapi.dev/api/planets/1/
# 1  https://swapi.dev/api/planets/1/
# 2  https://swapi.dev/api/planets/1/
# 3  https://swapi.dev/api/planets/8/
# 4  https://swapi.dev/api/planets/1/
#
# [5 rows x 48 columns]

# %%
everything.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 48 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name_people             93 non-null     object
#  1   height                  93 non-null     object
#  2   mass                    93 non-null     object
#  3   hair_color              93 non-null     object
#  4   skin_color              93 non-null     object
#  5   eye_color               93 non-null     object
#  6   birth_year              93 non-null     object
#  7   gender                  93 non-null     object
#  8   homeworld               93 non-null     object
#  9   films_people            93 non-null     object
#  10  species                 93 non-null     object
#  11  vehicles                93 non-null     object
#  12  starships               93 non-null     object
#  13  created_people          93 non-null     object
#  14  edited_people           93 non-null     object
#  15  url_people              93 non-null     object
#  16  name_starships          30 non-null     object
#  17  model                   30 non-null     object
#  18  manufacturer            30 non-null     object
#  19  cost_in_credits         30 non-null     object
#  20  length                  30 non-null     object
#  21  max_atmosphering_speed  30 non-null     object
#  22  crew                    30 non-null     object
#  23  passengers              30 non-null     object
#  24  cargo_capacity          30 non-null     object
#  25  consumables             30 non-null     object
#  26  hyperdrive_rating       30 non-null     object
#  27  MGLT                    30 non-null     object
#  28  starship_class          30 non-null     object
#  29  pilots                  30 non-null     object
#  30  films_starships         30 non-null     object
#  31  created_starships       30 non-null     object
#  32  edited_starships        30 non-null     object
#  33  url_starships           30 non-null     object
#  34  name                    93 non-null     object
#  35  rotation_period         93 non-null     object
#  36  orbital_period          93 non-null     object
#  37  diameter                93 non-null     object
#  38  climate                 93 non-null     object
#  39  gravity                 93 non-null     object
#  40  terrain                 93 non-null     object
#  41  surface_water           93 non-null     object
#  42  population              93 non-null     object
#  43  residents               93 non-null     object
#  44  films                   93 non-null     object
#  45  created                 93 non-null     object
#  46  edited                  93 non-null     object
#  47  url                     93 non-null     object
# dtypes: object(48)
# memory usage: 35.0+ KB

# %%
# if i wanted to re-aggregate to make the content unique by person:
# i could reaggregate the content into a list

# %%
# you can implode by reaggregating as a list:
everything.groupby('name_people').agg(list)
# Out:
#                                 height          mass             hair_color  \
# name_people
# Ackbar                           [180]          [83]                 [none]
# Adi Gallia                       [184]          [50]                 [none]
# Anakin Skywalker       [188, 188, 188]  [84, 84, 84]  [blond, blond, blond]
# Arvel Crynyd                 [unknown]     [unknown]                [brown]
# Ayla Secura                      [178]          [55]                 [none]
# ...                                ...           ...                    ...
# Wicket Systri Warrick             [88]          [20]                [brown]
# Wilhuff Tarkin                   [180]     [unknown]         [auburn, grey]
# Yarael Poof                      [264]     [unknown]                 [none]
# Yoda                              [66]          [17]                [white]
# Zam Wesell                       [168]          [55]               [blonde]
#
#                                   skin_color           eye_color  \
# name_people
# Ackbar                        [brown mottle]            [orange]
# Adi Gallia                            [dark]              [blue]
# Anakin Skywalker          [fair, fair, fair]  [blue, blue, blue]
# Arvel Crynyd                          [fair]             [brown]
# Ayla Secura                           [blue]             [hazel]
# ...                                      ...                 ...
# Wicket Systri Warrick                [brown]             [brown]
# Wilhuff Tarkin                        [fair]              [blue]
# Yarael Poof                          [white]            [yellow]
# Yoda                                 [green]             [brown]
# Zam Wesell             [fair, green, yellow]            [yellow]
#
#                                         birth_year              gender  \
# name_people
# Ackbar                                     [41BBY]              [male]
# Adi Gallia                               [unknown]            [female]
# Anakin Skywalker       [41.9BBY, 41.9BBY, 41.9BBY]  [male, male, male]
# Arvel Crynyd                             [unknown]              [male]
# Ayla Secura                                [48BBY]            [female]
# ...                                            ...                 ...
# Wicket Systri Warrick                       [8BBY]              [male]
# Wilhuff Tarkin                             [64BBY]              [male]
# Yarael Poof                              [unknown]              [male]
# Yoda                                      [896BBY]              [male]
# Zam Wesell                               [unknown]            [female]
#
#                                                                homeworld  \
# name_people
# Ackbar                               [https://swapi.dev/api/planets/31/]
# Adi Gallia                            [https://swapi.dev/api/planets/9/]
# Anakin Skywalker       [https://swapi.dev/api/planets/1/, https://swa...
# Arvel Crynyd                         [https://swapi.dev/api/planets/28/]
# Ayla Secura                          [https://swapi.dev/api/planets/37/]
# ...                                                                  ...
# Wicket Systri Warrick                 [https://swapi.dev/api/planets/7/]
# Wilhuff Tarkin                       [https://swapi.dev/api/planets/21/]
# Yarael Poof                          [https://swapi.dev/api/planets/48/]
# Yoda                                 [https://swapi.dev/api/planets/28/]
# Zam Wesell                           [https://swapi.dev/api/planets/54/]
#
#                                                             films_people  \
# name_people
# Ackbar                                [[https://swapi.dev/api/films/3/]]
# Adi Gallia             [[https://swapi.dev/api/films/4/, https://swap...
# Anakin Skywalker       [[https://swapi.dev/api/films/4/, https://swap...
# Arvel Crynyd                          [[https://swapi.dev/api/films/3/]]
# Ayla Secura            [[https://swapi.dev/api/films/4/, https://swap...
# ...                                                                  ...
# Wicket Systri Warrick                 [[https://swapi.dev/api/films/3/]]
# Wilhuff Tarkin         [[https://swapi.dev/api/films/1/, https://swap...
# Yarael Poof                           [[https://swapi.dev/api/films/4/]]
# Yoda                   [[https://swapi.dev/api/films/2/, https://swap...
# Zam Wesell                            [[https://swapi.dev/api/films/5/]]
#
#                                                      species  ...  \
# name_people                                                   ...
# Ackbar                  [[https://swapi.dev/api/species/8/]]  ...
# Adi Gallia             [[https://swapi.dev/api/species/23/]]  ...
# Anakin Skywalker                                [[], [], []]  ...
# Arvel Crynyd                                            [[]]  ...
# Ayla Secura            [[https://swapi.dev/api/species/15/]]  ...
# ...                                                      ...  ...
# Wicket Systri Warrick   [[https://swapi.dev/api/species/9/]]  ...
# Wilhuff Tarkin                                          [[]]  ...
# Yarael Poof            [[https://swapi.dev/api/species/25/]]  ...
# Yoda                    [[https://swapi.dev/api/species/6/]]  ...
# Zam Wesell             [[https://swapi.dev/api/species/30/]]  ...
#
#                                            climate  \
# name_people
# Ackbar                                 [temperate]
# Adi Gallia                             [temperate]
# Anakin Skywalker                [arid, arid, arid]
# Arvel Crynyd                             [unknown]
# Ayla Secura            [temperate, arid, subartic]
# ...                                            ...
# Wicket Systri Warrick                  [temperate]
# Wilhuff Tarkin                          [polluted]
# Yarael Poof                              [unknown]
# Yoda                                     [unknown]
# Zam Wesell                               [unknown]
#
#                                                     gravity  \
# name_people
# Ackbar                                                  [1]
# Adi Gallia                                     [1 standard]
# Anakin Skywalker       [1 standard, 1 standard, 1 standard]
# Arvel Crynyd                                      [unknown]
# Ayla Secura                                             [1]
# ...                                                     ...
# Wicket Systri Warrick                       [0.85 standard]
# Wilhuff Tarkin                                 [1 standard]
# Yarael Poof                                       [unknown]
# Yoda                                              [unknown]
# Zam Wesell                                        [unknown]
#
#                                                      terrain surface_water  \
# name_people
# Ackbar                              [oceans, reefs, islands]         [100]
# Adi Gallia                            [cityscape, mountains]     [unknown]
# Anakin Skywalker                    [desert, desert, desert]     [1, 1, 1]
# Arvel Crynyd                                       [unknown]     [unknown]
# Ayla Secura            [mountains, valleys, deserts, tundra]           [5]
# ...                                                      ...           ...
# Wicket Systri Warrick            [forests, mountains, lakes]           [8]
# Wilhuff Tarkin                                   [cityscape]     [unknown]
# Yarael Poof                                        [unknown]     [unknown]
# Yoda                                               [unknown]     [unknown]
# Zam Wesell                                         [unknown]     [unknown]
#
#                                      population  \
# name_people
# Ackbar                            [27000000000]
# Adi Gallia                      [1000000000000]
# Anakin Skywalker       [200000, 200000, 200000]
# Arvel Crynyd                          [unknown]
# Ayla Secura                        [1500000000]
# ...                                         ...
# Wicket Systri Warrick                [30000000]
# Wilhuff Tarkin                    [22000000000]
# Yarael Poof                           [unknown]
# Yoda                                  [unknown]
# Zam Wesell                            [unknown]
#
#                                                                residents  \
# name_people
# Ackbar                              [[https://swapi.dev/api/people/27/]]
# Adi Gallia             [[https://swapi.dev/api/people/34/, https://sw...
# Anakin Skywalker       [[https://swapi.dev/api/people/1/, https://swa...
# Arvel Crynyd           [[https://swapi.dev/api/people/20/, https://sw...
# Ayla Secura            [[https://swapi.dev/api/people/45/, https://sw...
# ...                                                                  ...
# Wicket Systri Warrick               [[https://swapi.dev/api/people/30/]]
# Wilhuff Tarkin                      [[https://swapi.dev/api/people/12/]]
# Yarael Poof                         [[https://swapi.dev/api/people/57/]]
# Yoda                   [[https://swapi.dev/api/people/20/, https://sw...
# Zam Wesell                          [[https://swapi.dev/api/people/70/]]
#
#                                                                    films  \
# name_people
# Ackbar                                                              [[]]
# Adi Gallia             [[https://swapi.dev/api/films/3/, https://swap...
# Anakin Skywalker       [[https://swapi.dev/api/films/1/, https://swap...
# Arvel Crynyd                                                        [[]]
# Ayla Secura                                                         [[]]
# ...                                                                  ...
# Wicket Systri Warrick                 [[https://swapi.dev/api/films/3/]]
# Wilhuff Tarkin                                                      [[]]
# Yarael Poof                                                         [[]]
# Yoda                                                                [[]]
# Zam Wesell                                                          [[]]
#
#                                                                  created  \
# name_people
# Ackbar                                     [2014-12-18T11:07:01.792000Z]
# Adi Gallia                                 [2014-12-10T11:54:13.921000Z]
# Anakin Skywalker       [2014-12-09T13:50:49.641000Z, 2014-12-09T13:50...
# Arvel Crynyd                               [2014-12-15T12:25:59.569000Z]
# Ayla Secura                                [2014-12-20T09:46:25.740000Z]
# ...                                                                  ...
# Wicket Systri Warrick                      [2014-12-10T11:50:29.349000Z]
# Wilhuff Tarkin                             [2014-12-10T16:26:54.384000Z]
# Yarael Poof                                [2014-12-20T10:34:08.249000Z]
# Yoda                                       [2014-12-15T12:25:59.569000Z]
# Zam Wesell                                 [2014-12-20T16:56:37.250000Z]
#
#                                                                   edited  \
# name_people
# Ackbar                                     [2014-12-20T20:58:18.471000Z]
# Adi Gallia                                 [2014-12-20T20:58:18.432000Z]
# Anakin Skywalker       [2014-12-20T20:58:18.411000Z, 2014-12-20T20:58...
# Arvel Crynyd                               [2014-12-20T20:58:18.466000Z]
# Ayla Secura                                [2014-12-20T20:58:18.481000Z]
# ...                                                                  ...
# Wicket Systri Warrick                      [2014-12-20T20:58:18.429000Z]
# Wilhuff Tarkin                             [2014-12-20T20:58:18.454000Z]
# Yarael Poof                                [2014-12-20T20:58:18.502000Z]
# Yoda                                       [2014-12-20T20:58:18.466000Z]
# Zam Wesell                                 [2014-12-20T20:58:18.514000Z]
#
#                                                                      url
# name_people
# Ackbar                               [https://swapi.dev/api/planets/31/]
# Adi Gallia                            [https://swapi.dev/api/planets/9/]
# Anakin Skywalker       [https://swapi.dev/api/planets/1/, https://swa...
# Arvel Crynyd                         [https://swapi.dev/api/planets/28/]
# Ayla Secura                          [https://swapi.dev/api/planets/37/]
# ...                                                                  ...
# Wicket Systri Warrick                 [https://swapi.dev/api/planets/7/]
# Wilhuff Tarkin                       [https://swapi.dev/api/planets/21/]
# Yarael Poof                          [https://swapi.dev/api/planets/48/]
# Yoda                                 [https://swapi.dev/api/planets/28/]
# Zam Wesell                           [https://swapi.dev/api/planets/54/]
#
# [82 rows x 47 columns]

# %%
weather = pd.read_csv('https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv')

# %%
weather
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]
